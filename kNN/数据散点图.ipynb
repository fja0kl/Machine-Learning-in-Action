# %%
import KNN_improveDating

# %%
import matplotlib
import matplotlib.pyplot as plt
from numpy import *

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot(111)

# %%
datingDataMat,datingDataLables = KNN_improveDating.file2Matrix('datingTestSet2.txt')

# %%
ax.scatter(datingDataMat[:,1],datingDataMat[:,2])

# %%
plt.show()
